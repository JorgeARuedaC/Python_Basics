# %%
from matplotlib import pyplot as plt

# %%
plt.style.use("fivethirtyeight")

# %%
slices = [120, 80]
labels = ['Sixty', 'Forty']

# %%
plt.pie(slices, labels = labels)

plt.title('My Awesome Pie Chart')
plt.tight_layout()
plt.show()

# %%
plt.pie(slices, labels = labels, wedgeprops = {'edgecolor' : 'black'})
plt.show()
# Out:
# ([<matplotlib.patches.Wedge at 0x225f45fcb38>,
#   <matplotlib.patches.Wedge at 0x225f4605080>],
#  [Text(-0.33991877217145816, 1.046162142464278, 'Sixty'),
#   Text(0.3399188701202255, -1.0461621106387813, 'Forty')])

# %%
slices = [120, 80, 30, 20]
labels = ['Sixty', 'Forty', 'Extra1', 'Extra2']
colors = ['blue', 'red', 'yellow', 'green']

# %%
plt.pie(slices, labels = labels, colors = colors, wedgeprops = {'edgecolor' : 'black'})
plt.show()

# %%
# Colors:
# Blue : #008fd5
# Red : #fc4f30
# Yellow : #e5ae37
# Green : #6d904f

# %%
colors = ['#008fd5', '#fc4f30', '#e5ae37', '#6d904f']
plt.pie(slices, labels = labels, colors = colors, wedgeprops = {'edgecolor' : 'black'})
plt.show()

# %%
# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917, 31991, 27097, 23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell', 'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']

# %%
plt.pie(slices, labels = labels, wedgeprops = {'edgecolor' : 'black'})
plt.show()

# %%
# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917 ]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']

# %%
# not recommended to plot a pie chart if you have more than 5 categories, use a bar chart instead
plt.pie(slices, labels = labels, wedgeprops = {'edgecolor' : 'black'})
plt.show()

# %%
slices = [59219, 55466, 47544, 36443, 35917 ]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.1, 0]

# %%
#exploding, highlighting specific slices
plt.pie(slices, labels = labels, explode = explode, wedgeprops = {'edgecolor' : 'black'})
plt.show()

# %%
#Shadow argument
plt.pie(slices, labels = labels, explode = explode, shadow = True, wedgeprops = {'edgecolor' : 'black'})
plt.show()

# %%
plt.pie(slices, labels = labels, explode = explode, shadow = True, startangle = 90, wedgeprops = {'edgecolor' : 'black'})
plt.show()

# %%
plt.pie(slices, 
        labels = labels, 
        explode = explode, 
        shadow = True, 
        startangle = 90, 
        autopct = '%1.1f%%',
        wedgeprops = {'edgecolor' : 'black'}
       )
plt.show()
